# %%
import pandas as pd
import numpy as np
import torch
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import random
import os
from sklearn.metrics import f1_score

torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

# %%
raw_model = "sberbank-ai/ruRoberta-large"
model = RobertaForSequenceClassification.from_pretrained(raw_model, num_labels = 2).cuda();
tokenizer = RobertaTokenizer.from_pretrained(raw_model)
# Out:
# Downloading:   0%|          | 0.00/674 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Some weights of the model checkpoint at sberbank-ai/ruRoberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at sberbank-ai/ruRoberta-large and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/1.73M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.31M [00:00<?, ?B/s]

# %%
def transform_df(df):
    df['is_fake'] = df['is_fake'].apply(lambda x: [0, 1] if x == 1 else [1, 0])
    return df

# %%
class PairsDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __getitem__(self, idx):
        return (self.x[idx], self.y[idx])

    def __len__(self):
        return len(self.x)

def data_collator(batch):
    y = torch.Tensor([p[1] for p in batch]).to(model.device)
    x = tokenizer([p[0] for p in batch], return_tensors='pt', padding=True).to(model.device)
    return (x, y)

# %%
PATH_TO_TRAIN_FOLDER = "../input/augmented-train"
PATH_TO_VALID_TEST_FOLDER = "../input/kontyp-parsed-train-test"

train = pd.read_feather(os.path.join(PATH_TO_TRAIN_FOLDER,'train.feather'))
valid = pd.read_feather(os.path.join(PATH_TO_VALID_TEST_FOLDER,'validate.feather'))
test = pd.read_feather(os.path.join(PATH_TO_VALID_TEST_FOLDER,'test.feather'))

# %%
BATCH_SIZE = 32

train = transform_df(train)
valid = transform_df(valid)
test = transform_df(test)

train_dataset = PairsDataset(train.title.values, train.is_fake.values)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, drop_last=False, shuffle=True, collate_fn=data_collator)

valid_dataset = PairsDataset(valid.title.values, valid.is_fake.values)
valid_dataloader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, drop_last=False, shuffle=False, collate_fn=data_collator)

test_dataset = PairsDataset(test.title.values, test.is_fake.values)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, drop_last=False, shuffle=False, collate_fn=data_collator)

# %%
def evaluate_model(model, test_dataloader):
    num = 0
    den = 0
    y_true = list()
    y_pred = list()
    f1_valid = .0
    for x, y in test_dataloader:
        with torch.no_grad():
            output = model(
                input_ids=x.input_ids,
                attention_mask=x.attention_mask,
                labels=y,
                return_dict=True
            )
            loss = output.loss
            
            num += len(x) * loss.item()
            den += len(x)
            
            y_pred.extend(torch.argmax(output.logits, 1).tolist())
            y_true.extend(torch.argmax(y, 1).tolist())
            
    val_loss = num / den
    f1_valid = f1_score(y_true, y_pred, average = 'micro')
    return val_loss, f1_valid

# %%
def train_loop(
    model, train_dataloader, val_dataloader, 
    max_epochs=10, 
    lr=1e-5,
    eval_steps = 50
):
    model.train()
    optimizer = torch.optim.Adam(params = [p for p in model.parameters() if p.requires_grad], lr=lr)
    scheduler = StepLR(optimizer, step_size = 3, gamma=0.5)
    best_f1 = float('-inf')
    
    for epoch in range(max_epochs):
        print('EPOCH', epoch)
        losses = list()
        for i, (x, y) in enumerate(train_dataloader):
            output = model(
                input_ids=x.input_ids,
                attention_mask=x.attention_mask,
                labels=y,
                return_dict=True
            )
            loss = output.loss
            
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            losses.append(loss.item())
            
            if i % eval_steps == 0:
                model.eval()
                train_loss = np.mean(losses[-eval_steps:])
                eval_loss, eval_f1 = evaluate_model(model, val_dataloader)
                if eval_f1 > best_f1:
                    best_f1 = eval_f1
                    torch.save(model.state_dict(), SAVE_PATH)
                print(f'step {i} train_loss: {train_loss:.3} eval_loss: {eval_loss:.3} eval_f1: {eval_f1:.3}')
                model.train()
        scheduler.step()

# %%
SAVE_PATH = 'ruroberta_model'

train_loop(model, train_dataloader, valid_dataloader, max_epochs=12, lr=2e-5, eval_steps = 100)
# Out:
# EPOCH 0
# step 0 train_loss: 0.705 eval_loss: 0.692 eval_f1: 0.504
# step 100 train_loss: 0.517 eval_loss: 0.252 eval_f1: 0.896
# step 200 train_loss: 0.381 eval_loss: 0.211 eval_f1: 0.917
# step 300 train_loss: 0.366 eval_loss: 0.451 eval_f1: 0.763
# step 400 train_loss: 0.448 eval_loss: 0.238 eval_f1: 0.902
# step 500 train_loss: 0.347 eval_loss: 0.206 eval_f1: 0.926
# step 600 train_loss: 0.33 eval_loss: 0.2 eval_f1: 0.932
# step 700 train_loss: 0.31 eval_loss: 0.186 eval_f1: 0.928
# step 800 train_loss: 0.305 eval_loss: 0.236 eval_f1: 0.905
# step 900 train_loss: 0.286 eval_loss: 0.164 eval_f1: 0.935
# step 1000 train_loss: 0.295 eval_loss: 0.187 eval_f1: 0.923
# step 1100 train_loss: 0.335 eval_loss: 0.208 eval_f1: 0.924
# EPOCH 1
# step 0 train_loss: 0.447 eval_loss: 0.304 eval_f1: 0.87
# step 100 train_loss: 0.261 eval_loss: 0.189 eval_f1: 0.928
# step 200 train_loss: 0.261 eval_loss: 0.224 eval_f1: 0.924
# step 300 train_loss: 0.357 eval_loss: 0.22 eval_f1: 0.911
# step 400 train_loss: 0.303 eval_loss: 0.183 eval_f1: 0.933
# step 500 train_loss: 0.27 eval_loss: 0.189 eval_f1: 0.925
# step 600 train_loss: 0.252 eval_loss: 0.173 eval_f1: 0.937
# step 700 train_loss: 0.243 eval_loss: 0.195 eval_f1: 0.931
# step 800 train_loss: 0.252 eval_loss: 0.219 eval_f1: 0.906
# step 900 train_loss: 0.242 eval_loss: 0.169 eval_f1: 0.937
# step 1000 train_loss: 0.262 eval_loss: 0.163 eval_f1: 0.939
# step 1100 train_loss: 0.236 eval_loss: 0.156 eval_f1: 0.941
# EPOCH 2
# step 0 train_loss: 0.237 eval_loss: 0.189 eval_f1: 0.922
# step 100 train_loss: 0.187 eval_loss: 0.171 eval_f1: 0.936
# step 200 train_loss: 0.174 eval_loss: 0.188 eval_f1: 0.94
# step 300 train_loss: 0.178 eval_loss: 0.168 eval_f1: 0.941
# step 400 train_loss: 0.19 eval_loss: 0.203 eval_f1: 0.937
# step 500 train_loss: 0.186 eval_loss: 0.186 eval_f1: 0.936
# step 600 train_loss: 0.177 eval_loss: 0.186 eval_f1: 0.939
# step 700 train_loss: 0.185 eval_loss: 0.219 eval_f1: 0.934
# step 800 train_loss: 0.205 eval_loss: 0.2 eval_f1: 0.929
# step 900 train_loss: 0.182 eval_loss: 0.185 eval_f1: 0.939
# step 1000 train_loss: 0.204 eval_loss: 0.182 eval_f1: 0.944
# step 1100 train_loss: 0.203 eval_loss: 0.19 eval_f1: 0.93
# EPOCH 3
# step 0 train_loss: 0.268 eval_loss: 0.195 eval_f1: 0.938
# step 100 train_loss: 0.111 eval_loss: 0.226 eval_f1: 0.935
# step 200 train_loss: 0.102 eval_loss: 0.209 eval_f1: 0.938
# step 300 train_loss: 0.124 eval_loss: 0.175 eval_f1: 0.941
# step 400 train_loss: 0.114 eval_loss: 0.191 eval_f1: 0.94
# step 500 train_loss: 0.13 eval_loss: 0.197 eval_f1: 0.93
# step 600 train_loss: 0.0993 eval_loss: 0.212 eval_f1: 0.94
# step 700 train_loss: 0.115 eval_loss: 0.216 eval_f1: 0.936
# step 800 train_loss: 0.0902 eval_loss: 0.202 eval_f1: 0.946
# step 900 train_loss: 0.099 eval_loss: 0.208 eval_f1: 0.939
# step 1000 train_loss: 0.109 eval_loss: 0.177 eval_f1: 0.943
# step 1100 train_loss: 0.0937 eval_loss: 0.176 eval_f1: 0.939
# EPOCH 4
# step 0 train_loss: 0.0976 eval_loss: 0.202 eval_f1: 0.935
# step 100 train_loss: 0.069 eval_loss: 0.225 eval_f1: 0.936
# step 200 train_loss: 0.0649 eval_loss: 0.272 eval_f1: 0.924
# step 300 train_loss: 0.0597 eval_loss: 0.205 eval_f1: 0.946
# step 400 train_loss: 0.0739 eval_loss: 0.219 eval_f1: 0.942
# step 500 train_loss: 0.0732 eval_loss: 0.206 eval_f1: 0.941
# step 600 train_loss: 0.0866 eval_loss: 0.27 eval_f1: 0.926
# step 700 train_loss: 0.0894 eval_loss: 0.211 eval_f1: 0.934
# step 800 train_loss: 0.0815 eval_loss: 0.201 eval_f1: 0.95
# step 900 train_loss: 0.0767 eval_loss: 0.191 eval_f1: 0.943
# step 1000 train_loss: 0.0696 eval_loss: 0.216 eval_f1: 0.941
# step 1100 train_loss: 0.0831 eval_loss: 0.233 eval_f1: 0.934
# EPOCH 5
# step 0 train_loss: 0.0132 eval_loss: 0.197 eval_f1: 0.949
# step 100 train_loss: 0.062 eval_loss: 0.22 eval_f1: 0.938
# step 200 train_loss: 0.184 eval_loss: 0.677 eval_f1: 0.495
# step 300 train_loss: 0.295 eval_loss: 0.257 eval_f1: 0.928
# step 400 train_loss: 0.0979 eval_loss: 0.271 eval_f1: 0.932
# step 500 train_loss: 0.0665 eval_loss: 0.219 eval_f1: 0.943
# step 600 train_loss: 0.0566 eval_loss: 0.243 eval_f1: 0.931
# step 700 train_loss: 0.0506 eval_loss: 0.283 eval_f1: 0.936
# step 800 train_loss: 0.0568 eval_loss: 0.362 eval_f1: 0.923
# step 900 train_loss: 0.0536 eval_loss: 0.289 eval_f1: 0.937
# step 1000 train_loss: 0.0507 eval_loss: 0.249 eval_f1: 0.937
# step 1100 train_loss: 0.0505 eval_loss: 0.304 eval_f1: 0.922
# EPOCH 6
# step 0 train_loss: 0.0136 eval_loss: 0.241 eval_f1: 0.938
# step 100 train_loss: 0.0281 eval_loss: 0.284 eval_f1: 0.938
# step 200 train_loss: 0.0319 eval_loss: 0.267 eval_f1: 0.938
# step 300 train_loss: 0.0249 eval_loss: 0.249 eval_f1: 0.942
# step 400 train_loss: 0.0273 eval_loss: 0.245 eval_f1: 0.94
# step 500 train_loss: 0.031 eval_loss: 0.275 eval_f1: 0.939
# step 600 train_loss: 0.0296 eval_loss: 0.239 eval_f1: 0.941
# step 700 train_loss: 0.043 eval_loss: 0.247 eval_f1: 0.935
# step 800 train_loss: 0.0256 eval_loss: 0.293 eval_f1: 0.93
# step 900 train_loss: 0.0273 eval_loss: 0.25 eval_f1: 0.936
# step 1000 train_loss: 0.0225 eval_loss: 0.245 eval_f1: 0.942
# step 1100 train_loss: 0.034 eval_loss: 0.236 eval_f1: 0.939
# EPOCH 7
# step 0 train_loss: 0.0089 eval_loss: 0.27 eval_f1: 0.938
# step 100 train_loss: 0.0186 eval_loss: 0.261 eval_f1: 0.943
# step 200 train_loss: 0.0202 eval_loss: 0.328 eval_f1: 0.936
# step 300 train_loss: 0.0174 eval_loss: 0.268 eval_f1: 0.945
# step 400 train_loss: 0.0333 eval_loss: 0.247 eval_f1: 0.945
# step 500 train_loss: 0.0242 eval_loss: 0.29 eval_f1: 0.938
# step 600 train_loss: 0.02 eval_loss: 0.335 eval_f1: 0.93
# step 700 train_loss: 0.0262 eval_loss: 0.276 eval_f1: 0.937
# step 800 train_loss: 0.0243 eval_loss: 0.279 eval_f1: 0.941
# step 900 train_loss: 0.0182 eval_loss: 0.292 eval_f1: 0.939
# step 1000 train_loss: 0.0285 eval_loss: 0.316 eval_f1: 0.933
# step 1100 train_loss: 0.0246 eval_loss: 0.282 eval_f1: 0.935
# EPOCH 8
# step 0 train_loss: 0.00138 eval_loss: 0.264 eval_f1: 0.94
# step 100 train_loss: 0.0142 eval_loss: 0.283 eval_f1: 0.942
# step 200 train_loss: 0.0117 eval_loss: 0.315 eval_f1: 0.938
# step 300 train_loss: 0.0191 eval_loss: 0.248 eval_f1: 0.938
# step 400 train_loss: 0.0165 eval_loss: 0.266 eval_f1: 0.938
# step 500 train_loss: 0.0201 eval_loss: 0.346 eval_f1: 0.934
# step 600 train_loss: 0.0197 eval_loss: 0.292 eval_f1: 0.937
# step 700 train_loss: 0.0163 eval_loss: 0.342 eval_f1: 0.935
# step 800 train_loss: 0.00883 eval_loss: 0.338 eval_f1: 0.938
# step 900 train_loss: 0.0267 eval_loss: 0.348 eval_f1: 0.932
# step 1000 train_loss: 0.0218 eval_loss: 0.317 eval_f1: 0.938
# step 1100 train_loss: 0.0223 eval_loss: 0.272 eval_f1: 0.939
# EPOCH 9
# step 0 train_loss: 0.0101 eval_loss: 0.292 eval_f1: 0.937
# step 100 train_loss: 0.0165 eval_loss: 0.314 eval_f1: 0.938
# step 200 train_loss: 0.0165 eval_loss: 0.277 eval_f1: 0.944
# step 300 train_loss: 0.00997 eval_loss: 0.296 eval_f1: 0.939
# step 400 train_loss: 0.013 eval_loss: 0.299 eval_f1: 0.938
# step 500 train_loss: 0.0144 eval_loss: 0.289 eval_f1: 0.94
# step 600 train_loss: 0.00782 eval_loss: 0.298 eval_f1: 0.939
# step 700 train_loss: 0.0126 eval_loss: 0.333 eval_f1: 0.939
# step 800 train_loss: 0.0131 eval_loss: 0.306 eval_f1: 0.938
# step 900 train_loss: 0.0132 eval_loss: 0.338 eval_f1: 0.937
# step 1000 train_loss: 0.00904 eval_loss: 0.323 eval_f1: 0.936
# step 1100 train_loss: 0.00861 eval_loss: 0.336 eval_f1: 0.939
# EPOCH 10
# step 0 train_loss: 0.000408 eval_loss: 0.331 eval_f1: 0.941
# step 100 train_loss: 0.00798 eval_loss: 0.335 eval_f1: 0.939
# step 200 train_loss: 0.0123 eval_loss: 0.321 eval_f1: 0.938
# step 300 train_loss: 0.00729 eval_loss: 0.307 eval_f1: 0.94
# step 400 train_loss: 0.00653 eval_loss: 0.338 eval_f1: 0.942
# step 500 train_loss: 0.00952 eval_loss: 0.327 eval_f1: 0.943
# step 600 train_loss: 0.00651 eval_loss: 0.27 eval_f1: 0.946
# step 700 train_loss: 0.00452 eval_loss: 0.348 eval_f1: 0.94
# step 800 train_loss: 0.00609 eval_loss: 0.448 eval_f1: 0.932
# step 900 train_loss: 0.0103 eval_loss: 0.393 eval_f1: 0.936
# step 1000 train_loss: 0.00841 eval_loss: 0.329 eval_f1: 0.943
# step 1100 train_loss: 0.00919 eval_loss: 0.29 eval_f1: 0.945
# EPOCH 11
# step 0 train_loss: 0.000317 eval_loss: 0.313 eval_f1: 0.941
# step 100 train_loss: 0.0084 eval_loss: 0.294 eval_f1: 0.939
# step 200 train_loss: 0.0115 eval_loss: 0.339 eval_f1: 0.938
# step 300 train_loss: 0.0115 eval_loss: 0.328 eval_f1: 0.943
# step 400 train_loss: 0.0114 eval_loss: 0.359 eval_f1: 0.938
# step 500 train_loss: 0.0121 eval_loss: 0.315 eval_f1: 0.945
# step 600 train_loss: 0.00402 eval_loss: 0.291 eval_f1: 0.939
# step 700 train_loss: 0.0106 eval_loss: 0.273 eval_f1: 0.945
# step 800 train_loss: 0.00742 eval_loss: 0.284 eval_f1: 0.944
# step 900 train_loss: 0.0062 eval_loss: 0.354 eval_f1: 0.943
# step 1000 train_loss: 0.00876 eval_loss: 0.339 eval_f1: 0.943
# step 1100 train_loss: 0.00652 eval_loss: 0.314 eval_f1: 0.941

# %%
model.load_state_dict(torch.load(SAVE_PATH))
model.eval()

# %%
test_loss, f1 = evaluate_model(model, test_dataloader)
print(f'Test loss: {test_loss}\nTest F1: {f1}')
# Out:
# Test loss: 0.23154260992834513
# Test F1: 0.9403409090909091
